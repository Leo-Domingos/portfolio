# %% [markdown]
# # Importing data
# Data extracted from:
# - https://www.kaggle.com/datasets/nikdavis/steam-store-games
# - https://www.kaggle.com/datasets/tamber/steam-video-games

# %%
import pandas as pd

user_time_played = pd.read_csv('./data/steam-200k.csv', header = None)

# %%
user_time_played.drop([4], axis = 1, inplace=True)
user_time_played.columns = ['user_id', 'game_name', 'action', 'hours']
user_time_played.head()
# Out:
#      user_id                   game_name    action  hours
# 0  151603712  The Elder Scrolls V Skyrim  purchase    1.0
# 1  151603712  The Elder Scrolls V Skyrim      play  273.0
# 2  151603712                   Fallout 4  purchase    1.0
# 3  151603712                   Fallout 4      play   87.0
# 4  151603712                       Spore  purchase    1.0

# %%
game_description = pd.read_csv('./data/steam_description_data.csv')
game_media = pd.read_csv('./data/steam_media_data.csv')
game_requirements = pd.read_csv('./data/steam_requirements_data.csv')
game_support = pd.read_csv('./data/steam_support_info.csv')
game_steam = pd.read_csv('./data/steam.csv')

# %%
game_steam=game_steam.rename(columns = {'appid':'steam_appid'})
game_steam.head()
# Out:
#    steam_appid                       name release_date  english  \
# 0           10             Counter-Strike   2000-11-01        1
# 1           20      Team Fortress Classic   1999-04-01        1
# 2           30              Day of Defeat   2003-05-01        1
# 3           40         Deathmatch Classic   2001-06-01        1
# 4           50  Half-Life: Opposing Force   1999-11-01        1
#
#           developer publisher          platforms  required_age  \
# 0             Valve     Valve  windows;mac;linux             0
# 1             Valve     Valve  windows;mac;linux             0
# 2             Valve     Valve  windows;mac;linux             0
# 3             Valve     Valve  windows;mac;linux             0
# 4  Gearbox Software     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1        Action;FPS;Multiplayer             0              3318
# 2  FPS;World War II;Multiplayer             0              3416
# 3        Action;FPS;Multiplayer             0              1273
# 4             FPS;Action;Sci-fi             0              5250
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
# 3               267               258              184   5000000-10000000
# 4               288               624              415   5000000-10000000
#
#    price
# 0   7.19
# 1   3.99
# 2   3.99
# 3   3.99
# 4   3.99

# %%
import pandas as pd
from functools import reduce

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['steam_appid'],
                                            how='outer'), [game_steam, game_description, game_media, game_requirements, game_support])

# %%
df_consolidado = df_merged.head()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Requisition from steam api

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests

# %%
def get_request(url, parameters=None):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recusively try again
        return get_request(url, parameters)
    
    if response:
        return response.json()
    else:
        # response is none usually means too many requests. Wait and try again 
        print('No response, waiting 10 seconds...')
        time.sleep(10)
        print('Retrying.')
        return get_request(url, parameters)

def get_app_data(start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, row in app_list[start:stop].iterrows():
        print('Current index: {}'.format(index), end='\r')
        
        appid = row['appid']
        name = row['name']

        # retrive app data for a row, handled by supplied parser, and append to list
        data = parser(appid, name)
        app_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return app_data


def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=100, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))


def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    with open(rel_path, 'w') as f:
        print(0, file=f)
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

def parse_steam_request(appid, name):
    """Unique parser to handle data from Steam Store API.
    
    Returns : json formatted data (dict-like)
    """
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": appid}
    
    json_data = get_request(url, parameters=parameters)
    json_app_data = json_data[str(appid)]
    
    if json_app_data['success']:
        data = json_app_data['data']
    else:
        data = {'name': name, 'steam_appid': appid}
        
    return data

# %%
page = 1
url = "https://steamspy.com/api.php"
parameters = {"request": "all", 'page' : page}

# request 'all' from steam spy and parse into dataframe
json_data = get_request(url, parameters=parameters)
steam_spy_all = pd.DataFrame.from_dict(json_data, orient='index')

# generate sorted app_list from steamspy data
app_list = steam_spy_all[['appid', 'name']].sort_values('appid').reset_index(drop=True)

# export disabled to keep consistency across download sessions
app_list.to_csv('./data/download/app_list.csv', index=False)

# instead read from stored csv
app_list = pd.read_csv('./data/download/app_list.csv')

# display first few rows
app_list.head()
# Out:
#    appid                           name
# 0   1200  Red Orchestra: Ostfront 41-45
# 1   1510                         Uplink
# 2   1520                         DEFCON
# 3   1530                     Multiwinia
# 4   1900                     Earth 2160

# %%
# Set file parameters
download_path = './data/download'
steam_app_data = 'steam_app_data'+str(page+1)+'.csv'
steam_index = 'steam_index.txt'

steam_columns = [
    'type', 'name', 'steam_appid', 'required_age', 'is_free', 'controller_support',
    'dlc', 'detailed_description', 'about_the_game', 'short_description', 'fullgame',
    'supported_languages', 'header_image', 'website', 'pc_requirements', 'mac_requirements',
    'linux_requirements', 'legal_notice', 'drm_notice', 'ext_user_account_notice',
    'developers', 'publishers', 'demos', 'price_overview', 'packages', 'package_groups',
    'platforms', 'metacritic', 'reviews', 'categories', 'genres', 'screenshots',
    'movies', 'recommendations', 'achievements', 'release_date', 'support_info',
    'background', 'content_descriptors'
]

# Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
reset_index(download_path, steam_index)

# Retrieve last index downloaded from file
index = get_index(download_path, steam_index)

# Wipe or create data file and write headers if index is 0
prepare_data_file(download_path, steam_app_data, index, steam_columns)

# Set end and chunksize for demonstration - remove to run through entire app list
process_batches(
    parser=parse_steam_request,
    app_list=app_list,
    download_path=download_path,
    data_filename=steam_app_data,
    index_filename=steam_index,
    columns=steam_columns,
    begin=index,
    batchsize=5
)
# Out:
# Starting at index 0:
#
# Exported lines 0-4 to steam_app_data2.csv. Batch 0 time: 0:00:08 (avg: 0:00:08, remaining: 0:26:58)
# Exported lines 5-9 to steam_app_data2.csv. Batch 1 time: 0:00:08 (avg: 0:00:08, remaining: 0:26:23)
# Exported lines 10-14 to steam_app_data2.csv. Batch 2 time: 0:00:08 (avg: 0:00:08, remaining: 0:26:40)
# Exported lines 15-19 to steam_app_data2.csv. Batch 3 time: 0:00:08 (avg: 0:00:08, remaining: 0:26:34)
# Exported lines 20-24 to steam_app_data2.csv. Batch 4 time: 0:00:08 (avg: 0:00:08, remaining: 0:26:23)
# Exported lines 25-29 to steam_app_data2.csv. Batch 5 time: 0:00:08 (avg: 0:00:08, remaining: 0:26:12)
# Exported lines 30-34 to steam_app_data2.csv. Batch 6 time: 0:00:08 (avg: 0:00:08, remaining: 0:25:59)
# Exported lines 35-39 to steam_app_data2.csv. Batch 7 time: 0:00:08 (avg: 0:00:08, remaining: 0:25:48)
# Exported lines 40-44 to steam_app_data2.csv. Batch 8 time: 0:00:09 (avg: 0:00:08, remaining: 0:25:52)
# Exported lines 45-49 to steam_app_data2.csv. Batch 9 time: 0:00:08 (avg: 0:00:08, remaining: 0:25:47)
# Exported lines 50-54 to steam_app_data2.csv. Batch 10 time: 0:00:08 (avg: 0:00:08, remaining: 0:25:40)
# Exported lines 55-59 to steam_app_data2.csv. Batch 11 time: 0:00:08 (avg: 0:00:08, remaining: 0:25:30)
# Exported lines 60-64 to steam_app_data2.csv. Batch 12 time: 0:00:08 (avg: 0:00:08, remaining: 0:25:19)
# Exported lines 65-69 to steam_app_data2.csv. Batch 13 time: 0:00:08 (avg: 0:00:08, remaining: 0:25:09)
# Exported lines 70-74 to steam_app_data2.csv. Batch 14 time: 0:00:08 (avg: 0:00:08, remaining: 0:25:00)
# Exported lines 75-79 to steam_app_data2.csv. Batch 15 time: 0:00:08 (avg: 0:00:08, remaining: 0:24:49)
# Exported lines 80-84 to steam_app_data2.csv. Batch 16 time: 0:00:08 (avg: 0:00:08, remaining: 0:24:39)
# Exported lines 85-89 to steam_app_data2.csv. Batch 17 time: 0:00:08 (avg: 0:00:08, remaining: 0:24:32)
# Exported lines 90-94 to steam_app_data2.csv. Batch 18 time: 0:00:08 (avg: 0:00:08, remaining: 0:24:21)
# Exported lines 95-99 to steam_app_data2.csv. Batch 19 time: 0:00:08 (avg: 0:00:08, remaining: 0:24:12)
# Exported lines 100-104 to steam_app_data2.csv. Batch 20 time: 0:00:08 (avg: 0:00:08, remaining: 0:24:03)
# Exported lines 105-109 to steam_app_data2.csv. Batch 21 time: 0:00:08 (avg: 0:00:08, remaining: 0:23:57)
# Exported lines 110-114 to steam_app_data2.csv. Batch 22 time: 0:00:08 (avg: 0:00:08, remaining: 0:23:50)
# Exported lines 115-119 to steam_app_data2.csv. Batch 23 time: 0:00:08 (avg: 0:00:08, remaining: 0:23:42)
# Exported lines 120-124 to steam_app_data2.csv. Batch 24 time: 0:00:08 (avg: 0:00:08, remaining: 0:23:35)
# Exported lines 125-129 to steam_app_data2.csv. Batch 25 time: 0:00:08 (avg: 0:00:08, remaining: 0:23:27)
# Exported lines 130-134 to steam_app_data2.csv. Batch 26 time: 0:00:08 (avg: 0:00:08, remaining: 0:23:19)
# Exported lines 135-139 to steam_app_data2.csv. Batch 27 time: 0:00:08 (avg: 0:00:08, remaining: 0:23:11)
# Exported lines 140-144 to steam_app_data2.csv. Batch 28 time: 0:00:08 (avg: 0:00:08, remaining: 0:23:04)
# Exported lines 145-149 to steam_app_data2.csv. Batch 29 time: 0:00:08 (avg: 0:00:08, remaining: 0:22:54)
# Exported lines 150-154 to steam_app_data2.csv. Batch 30 time: 0:00:08 (avg: 0:00:08, remaining: 0:22:46)
# Exported lines 155-159 to steam_app_data2.csv. Batch 31 time: 0:00:08 (avg: 0:00:08, remaining: 0:22:39)
# Exported lines 160-164 to steam_app_data2.csv. Batch 32 time: 0:00:08 (avg: 0:00:08, remaining: 0:22:33)
# Exported lines 165-169 to steam_app_data2.csv. Batch 33 time: 0:00:08 (avg: 0:00:08, remaining: 0:22:24)
# Exported lines 170-174 to steam_app_data2.csv. Batch 34 time: 0:00:08 (avg: 0:00:08, remaining: 0:22:16)
# Exported lines 175-179 to steam_app_data2.csv. Batch 35 time: 0:00:08 (avg: 0:00:08, remaining: 0:22:06)
# Exported lines 180-184 to steam_app_data2.csv. Batch 36 time: 0:00:08 (avg: 0:00:08, remaining: 0:21:57)
# Exported lines 185-189 to steam_app_data2.csv. Batch 37 time: 0:00:09 (avg: 0:00:08, remaining: 0:21:52)
# Exported lines 190-194 to steam_app_data2.csv. Batch 38 time: 0:00:08 (avg: 0:00:08, remaining: 0:21:44)
# Exported lines 195-199 to steam_app_data2.csv. Batch 39 time: 0:00:08 (avg: 0:00:08, remaining: 0:21:37)
# Exported lines 200-204 to steam_app_data2.csv. Batch 40 time: 0:00:09 (avg: 0:00:08, remaining: 0:21:32)
# Exported lines 205-209 to steam_app_data2.csv. Batch 41 time: 0:00:08 (avg: 0:00:08, remaining: 0:21:24)
# Exported lines 210-214 to steam_app_data2.csv. Batch 42 time: 0:00:08 (avg: 0:00:08, remaining: 0:21:15)
# Exported lines 215-219 to steam_app_data2.csv. Batch 43 time: 0:00:08 (avg: 0:00:08, remaining: 0:21:08)
# Exported lines 220-224 to steam_app_data2.csv. Batch 44 time: 0:00:09 (avg: 0:00:08, remaining: 0:21:02)
# Exported lines 225-229 to steam_app_data2.csv. Batch 45 time: 0:00:08 (avg: 0:00:08, remaining: 0:20:53)
# Exported lines 230-234 to steam_app_data2.csv. Batch 46 time: 0:00:08 (avg: 0:00:08, remaining: 0:20:45)
# Exported lines 235-239 to steam_app_data2.csv. Batch 47 time: 0:00:08 (avg: 0:00:08, remaining: 0:20:37)
# Exported lines 240-244 to steam_app_data2.csv. Batch 48 time: 0:00:08 (avg: 0:00:08, remaining: 0:20:28)
# Exported lines 245-249 to steam_app_data2.csv. Batch 49 time: 0:00:08 (avg: 0:00:08, remaining: 0:20:21)
# Exported lines 250-254 to steam_app_data2.csv. Batch 50 time: 0:00:09 (avg: 0:00:08, remaining: 0:20:14)
# Exported lines 255-259 to steam_app_data2.csv. Batch 51 time: 0:00:08 (avg: 0:00:08, remaining: 0:20:06)
# Exported lines 260-264 to steam_app_data2.csv. Batch 52 time: 0:00:09 (avg: 0:00:08, remaining: 0:20:00)
# Exported lines 265-269 to steam_app_data2.csv. Batch 53 time: 0:00:09 (avg: 0:00:08, remaining: 0:19:53)
# Exported lines 270-274 to steam_app_data2.csv. Batch 54 time: 0:00:08 (avg: 0:00:08, remaining: 0:19:45)
# Exported lines 275-279 to steam_app_data2.csv. Batch 55 time: 0:00:08 (avg: 0:00:08, remaining: 0:19:37)
# Exported lines 280-284 to steam_app_data2.csv. Batch 56 time: 0:00:08 (avg: 0:00:08, remaining: 0:19:29)
# Exported lines 285-289 to steam_app_data2.csv. Batch 57 time: 0:00:08 (avg: 0:00:08, remaining: 0:19:21)
# Exported lines 290-294 to steam_app_data2.csv. Batch 58 time: 0:00:08 (avg: 0:00:08, remaining: 0:19:13)
# Exported lines 295-299 to steam_app_data2.csv. Batch 59 time: 0:00:08 (avg: 0:00:08, remaining: 0:19:05)
# Exported lines 300-304 to steam_app_data2.csv. Batch 60 time: 0:00:09 (avg: 0:00:08, remaining: 0:18:58)
# Exported lines 305-309 to steam_app_data2.csv. Batch 61 time: 0:00:08 (avg: 0:00:08, remaining: 0:18:50)
# Exported lines 310-314 to steam_app_data2.csv. Batch 62 time: 0:00:08 (avg: 0:00:08, remaining: 0:18:41)
# Exported lines 315-319 to steam_app_data2.csv. Batch 63 time: 0:00:08 (avg: 0:00:08, remaining: 0:18:34)
# Exported lines 320-324 to steam_app_data2.csv. Batch 64 time: 0:00:08 (avg: 0:00:08, remaining: 0:18:26)
# Exported lines 325-329 to steam_app_data2.csv. Batch 65 time: 0:00:08 (avg: 0:00:08, remaining: 0:18:17)
# Exported lines 330-334 to steam_app_data2.csv. Batch 66 time: 0:00:08 (avg: 0:00:08, remaining: 0:18:09)
# Exported lines 335-339 to steam_app_data2.csv. Batch 67 time: 0:00:08 (avg: 0:00:08, remaining: 0:18:00)
# Exported lines 340-344 to steam_app_data2.csv. Batch 68 time: 0:00:08 (avg: 0:00:08, remaining: 0:17:52)
# Exported lines 345-349 to steam_app_data2.csv. Batch 69 time: 0:00:08 (avg: 0:00:08, remaining: 0:17:43)
# Exported lines 350-354 to steam_app_data2.csv. Batch 70 time: 0:00:08 (avg: 0:00:08, remaining: 0:17:35)
# Exported lines 355-359 to steam_app_data2.csv. Batch 71 time: 0:00:08 (avg: 0:00:08, remaining: 0:17:27)
# Exported lines 360-364 to steam_app_data2.csv. Batch 72 time: 0:00:08 (avg: 0:00:08, remaining: 0:17:19)
# Exported lines 365-369 to steam_app_data2.csv. Batch 73 time: 0:00:08 (avg: 0:00:08, remaining: 0:17:11)
# Exported lines 370-374 to steam_app_data2.csv. Batch 74 time: 0:00:08 (avg: 0:00:08, remaining: 0:17:03)
# Exported lines 375-379 to steam_app_data2.csv. Batch 75 time: 0:00:08 (avg: 0:00:08, remaining: 0:16:55)
# Exported lines 380-384 to steam_app_data2.csv. Batch 76 time: 0:00:08 (avg: 0:00:08, remaining: 0:16:47)
# Exported lines 385-389 to steam_app_data2.csv. Batch 77 time: 0:00:08 (avg: 0:00:08, remaining: 0:16:38)
# Exported lines 390-394 to steam_app_data2.csv. Batch 78 time: 0:00:08 (avg: 0:00:08, remaining: 0:16:30)
# Exported lines 395-399 to steam_app_data2.csv. Batch 79 time: 0:00:08 (avg: 0:00:08, remaining: 0:16:22)
# Exported lines 400-404 to steam_app_data2.csv. Batch 80 time: 0:00:08 (avg: 0:00:08, remaining: 0:16:14)
# Exported lines 405-409 to steam_app_data2.csv. Batch 81 time: 0:00:08 (avg: 0:00:08, remaining: 0:16:05)
# Exported lines 410-414 to steam_app_data2.csv. Batch 82 time: 0:00:08 (avg: 0:00:08, remaining: 0:15:57)
# Exported lines 415-419 to steam_app_data2.csv. Batch 83 time: 0:00:08 (avg: 0:00:08, remaining: 0:15:49)
# Exported lines 420-424 to steam_app_data2.csv. Batch 84 time: 0:00:08 (avg: 0:00:08, remaining: 0:15:41)
# Exported lines 425-429 to steam_app_data2.csv. Batch 85 time: 0:00:08 (avg: 0:00:08, remaining: 0:15:33)
# Exported lines 430-434 to steam_app_data2.csv. Batch 86 time: 0:00:08 (avg: 0:00:08, remaining: 0:15:25)
# Exported lines 435-439 to steam_app_data2.csv. Batch 87 time: 0:00:08 (avg: 0:00:08, remaining: 0:15:17)
# Exported lines 440-444 to steam_app_data2.csv. Batch 88 time: 0:00:08 (avg: 0:00:08, remaining: 0:15:09)
# Exported lines 445-449 to steam_app_data2.csv. Batch 89 time: 0:00:08 (avg: 0:00:08, remaining: 0:15:00)
# Exported lines 450-454 to steam_app_data2.csv. Batch 90 time: 0:00:08 (avg: 0:00:08, remaining: 0:14:52)
# Exported lines 455-459 to steam_app_data2.csv. Batch 91 time: 0:00:08 (avg: 0:00:08, remaining: 0:14:44)
# Exported lines 460-464 to steam_app_data2.csv. Batch 92 time: 0:00:08 (avg: 0:00:08, remaining: 0:14:35)
# Exported lines 465-469 to steam_app_data2.csv. Batch 93 time: 0:00:08 (avg: 0:00:08, remaining: 0:14:27)
# Exported lines 470-474 to steam_app_data2.csv. Batch 94 time: 0:00:08 (avg: 0:00:08, remaining: 0:14:19)
# Exported lines 475-479 to steam_app_data2.csv. Batch 95 time: 0:00:08 (avg: 0:00:08, remaining: 0:14:11)
# Exported lines 480-484 to steam_app_data2.csv. Batch 96 time: 0:00:08 (avg: 0:00:08, remaining: 0:14:02)
# Exported lines 485-489 to steam_app_data2.csv. Batch 97 time: 0:00:08 (avg: 0:00:08, remaining: 0:13:54)
# Exported lines 490-494 to steam_app_data2.csv. Batch 98 time: 0:00:08 (avg: 0:00:08, remaining: 0:13:46)
# Exported lines 495-499 to steam_app_data2.csv. Batch 99 time: 0:00:08 (avg: 0:00:08, remaining: 0:13:38)
# Exported lines 500-504 to steam_app_data2.csv. Batch 100 time: 0:00:09 (avg: 0:00:08, remaining: 0:13:30)
# Exported lines 505-509 to steam_app_data2.csv. Batch 101 time: 0:00:08 (avg: 0:00:08, remaining: 0:13:22)
# Exported lines 510-514 to steam_app_data2.csv. Batch 102 time: 0:00:08 (avg: 0:00:08, remaining: 0:13:14)
# Exported lines 515-519 to steam_app_data2.csv. Batch 103 time: 0:00:08 (avg: 0:00:08, remaining: 0:13:06)
# Exported lines 520-524 to steam_app_data2.csv. Batch 104 time: 0:00:08 (avg: 0:00:08, remaining: 0:12:57)
# Exported lines 525-529 to steam_app_data2.csv. Batch 105 time: 0:00:08 (avg: 0:00:08, remaining: 0:12:49)
# Exported lines 530-534 to steam_app_data2.csv. Batch 106 time: 0:00:08 (avg: 0:00:08, remaining: 0:12:41)
# Exported lines 535-539 to steam_app_data2.csv. Batch 107 time: 0:00:08 (avg: 0:00:08, remaining: 0:12:33)
# Exported lines 540-544 to steam_app_data2.csv. Batch 108 time: 0:00:08 (avg: 0:00:08, remaining: 0:12:25)
# Exported lines 545-549 to steam_app_data2.csv. Batch 109 time: 0:00:08 (avg: 0:00:08, remaining: 0:12:17)
# Exported lines 550-554 to steam_app_data2.csv. Batch 110 time: 0:00:08 (avg: 0:00:08, remaining: 0:12:08)
# Exported lines 555-559 to steam_app_data2.csv. Batch 111 time: 0:00:08 (avg: 0:00:08, remaining: 0:12:00)
# Exported lines 560-564 to steam_app_data2.csv. Batch 112 time: 0:00:08 (avg: 0:00:08, remaining: 0:11:52)
# Exported lines 565-569 to steam_app_data2.csv. Batch 113 time: 0:00:08 (avg: 0:00:08, remaining: 0:11:44)
# Exported lines 570-574 to steam_app_data2.csv. Batch 114 time: 0:00:08 (avg: 0:00:08, remaining: 0:11:36)
# Exported lines 575-579 to steam_app_data2.csv. Batch 115 time: 0:00:08 (avg: 0:00:08, remaining: 0:11:28)
# Exported lines 580-584 to steam_app_data2.csv. Batch 116 time: 0:00:08 (avg: 0:00:08, remaining: 0:11:20)
# Exported lines 585-589 to steam_app_data2.csv. Batch 117 time: 0:00:08 (avg: 0:00:08, remaining: 0:11:11)
# Exported lines 590-594 to steam_app_data2.csv. Batch 118 time: 0:00:08 (avg: 0:00:08, remaining: 0:11:03)
# Exported lines 595-599 to steam_app_data2.csv. Batch 119 time: 0:00:08 (avg: 0:00:08, remaining: 0:10:55)
# Exported lines 600-604 to steam_app_data2.csv. Batch 120 time: 0:00:08 (avg: 0:00:08, remaining: 0:10:47)
# Exported lines 605-609 to steam_app_data2.csv. Batch 121 time: 0:00:08 (avg: 0:00:08, remaining: 0:10:39)
# Exported lines 610-614 to steam_app_data2.csv. Batch 122 time: 0:00:08 (avg: 0:00:08, remaining: 0:10:31)
# Exported lines 615-619 to steam_app_data2.csv. Batch 123 time: 0:00:08 (avg: 0:00:08, remaining: 0:10:23)
# Exported lines 620-624 to steam_app_data2.csv. Batch 124 time: 0:00:08 (avg: 0:00:08, remaining: 0:10:15)
# Exported lines 625-629 to steam_app_data2.csv. Batch 125 time: 0:00:08 (avg: 0:00:08, remaining: 0:10:07)
# Exported lines 630-634 to steam_app_data2.csv. Batch 126 time: 0:00:08 (avg: 0:00:08, remaining: 0:09:58)
# Exported lines 635-639 to steam_app_data2.csv. Batch 127 time: 0:00:08 (avg: 0:00:08, remaining: 0:09:50)
# Exported lines 640-644 to steam_app_data2.csv. Batch 128 time: 0:00:08 (avg: 0:00:08, remaining: 0:09:42)
# Exported lines 645-649 to steam_app_data2.csv. Batch 129 time: 0:00:08 (avg: 0:00:08, remaining: 0:09:34)
# Exported lines 650-654 to steam_app_data2.csv. Batch 130 time: 0:00:08 (avg: 0:00:08, remaining: 0:09:26)
# Exported lines 655-659 to steam_app_data2.csv. Batch 131 time: 0:00:08 (avg: 0:00:08, remaining: 0:09:18)
# Exported lines 660-664 to steam_app_data2.csv. Batch 132 time: 0:00:08 (avg: 0:00:08, remaining: 0:09:10)
# Exported lines 665-669 to steam_app_data2.csv. Batch 133 time: 0:00:08 (avg: 0:00:08, remaining: 0:09:01)
# Exported lines 670-674 to steam_app_data2.csv. Batch 134 time: 0:00:08 (avg: 0:00:08, remaining: 0:08:53)
# Exported lines 675-679 to steam_app_data2.csv. Batch 135 time: 0:00:08 (avg: 0:00:08, remaining: 0:08:45)
# Exported lines 680-684 to steam_app_data2.csv. Batch 136 time: 0:00:08 (avg: 0:00:08, remaining: 0:08:37)
# Exported lines 685-689 to steam_app_data2.csv. Batch 137 time: 0:00:08 (avg: 0:00:08, remaining: 0:08:29)
# Exported lines 690-694 to steam_app_data2.csv. Batch 138 time: 0:00:08 (avg: 0:00:08, remaining: 0:08:21)
# Exported lines 695-699 to steam_app_data2.csv. Batch 139 time: 0:00:08 (avg: 0:00:08, remaining: 0:08:13)
# Exported lines 700-704 to steam_app_data2.csv. Batch 140 time: 0:00:08 (avg: 0:00:08, remaining: 0:08:04)
# Exported lines 705-709 to steam_app_data2.csv. Batch 141 time: 0:00:08 (avg: 0:00:08, remaining: 0:07:56)
# Exported lines 710-714 to steam_app_data2.csv. Batch 142 time: 0:00:08 (avg: 0:00:08, remaining: 0:07:48)
# Exported lines 715-719 to steam_app_data2.csv. Batch 143 time: 0:00:08 (avg: 0:00:08, remaining: 0:07:40)
# Exported lines 720-724 to steam_app_data2.csv. Batch 144 time: 0:00:08 (avg: 0:00:08, remaining: 0:07:32)
# Exported lines 725-729 to steam_app_data2.csv. Batch 145 time: 0:00:08 (avg: 0:00:08, remaining: 0:07:24)
# Exported lines 730-734 to steam_app_data2.csv. Batch 146 time: 0:00:08 (avg: 0:00:08, remaining: 0:07:16)
# Exported lines 735-739 to steam_app_data2.csv. Batch 147 time: 0:00:08 (avg: 0:00:08, remaining: 0:07:08)
# Exported lines 740-744 to steam_app_data2.csv. Batch 148 time: 0:00:08 (avg: 0:00:08, remaining: 0:06:59)
# Exported lines 745-749 to steam_app_data2.csv. Batch 149 time: 0:00:08 (avg: 0:00:08, remaining: 0:06:51)
# Exported lines 750-754 to steam_app_data2.csv. Batch 150 time: 0:00:08 (avg: 0:00:08, remaining: 0:06:43)
# Exported lines 755-759 to steam_app_data2.csv. Batch 151 time: 0:00:08 (avg: 0:00:08, remaining: 0:06:35)
# Exported lines 760-764 to steam_app_data2.csv. Batch 152 time: 0:00:08 (avg: 0:00:08, remaining: 0:06:27)
# Exported lines 765-769 to steam_app_data2.csv. Batch 153 time: 0:00:08 (avg: 0:00:08, remaining: 0:06:19)
# Exported lines 770-774 to steam_app_data2.csv. Batch 154 time: 0:00:08 (avg: 0:00:08, remaining: 0:06:11)
# Exported lines 775-779 to steam_app_data2.csv. Batch 155 time: 0:00:08 (avg: 0:00:08, remaining: 0:06:03)
# Exported lines 780-784 to steam_app_data2.csv. Batch 156 time: 0:00:08 (avg: 0:00:08, remaining: 0:05:55)
# Exported lines 785-789 to steam_app_data2.csv. Batch 157 time: 0:00:08 (avg: 0:00:08, remaining: 0:05:47)
# Exported lines 790-794 to steam_app_data2.csv. Batch 158 time: 0:00:08 (avg: 0:00:08, remaining: 0:05:39)
# Exported lines 795-799 to steam_app_data2.csv. Batch 159 time: 0:00:08 (avg: 0:00:08, remaining: 0:05:31)
# Exported lines 800-804 to steam_app_data2.csv. Batch 160 time: 0:00:08 (avg: 0:00:08, remaining: 0:05:23)
# Exported lines 805-809 to steam_app_data2.csv. Batch 161 time: 0:00:08 (avg: 0:00:08, remaining: 0:05:14)
# Exported lines 810-814 to steam_app_data2.csv. Batch 162 time: 0:00:08 (avg: 0:00:08, remaining: 0:05:06)
# Exported lines 815-819 to steam_app_data2.csv. Batch 163 time: 0:00:08 (avg: 0:00:08, remaining: 0:04:58)
# Exported lines 820-824 to steam_app_data2.csv. Batch 164 time: 0:00:08 (avg: 0:00:08, remaining: 0:04:50)
# Exported lines 825-829 to steam_app_data2.csv. Batch 165 time: 0:00:08 (avg: 0:00:08, remaining: 0:04:42)
# Exported lines 830-834 to steam_app_data2.csv. Batch 166 time: 0:00:08 (avg: 0:00:08, remaining: 0:04:34)
# Exported lines 835-839 to steam_app_data2.csv. Batch 167 time: 0:00:08 (avg: 0:00:08, remaining: 0:04:26)
# Exported lines 840-844 to steam_app_data2.csv. Batch 168 time: 0:00:08 (avg: 0:00:08, remaining: 0:04:18)
# Exported lines 845-849 to steam_app_data2.csv. Batch 169 time: 0:00:08 (avg: 0:00:08, remaining: 0:04:10)
# Exported lines 850-854 to steam_app_data2.csv. Batch 170 time: 0:00:08 (avg: 0:00:08, remaining: 0:04:02)
# Exported lines 855-859 to steam_app_data2.csv. Batch 171 time: 0:00:08 (avg: 0:00:08, remaining: 0:03:54)
# Exported lines 860-864 to steam_app_data2.csv. Batch 172 time: 0:00:08 (avg: 0:00:08, remaining: 0:03:46)
# Exported lines 865-869 to steam_app_data2.csv. Batch 173 time: 0:00:08 (avg: 0:00:08, remaining: 0:03:38)
# Exported lines 870-874 to steam_app_data2.csv. Batch 174 time: 0:00:08 (avg: 0:00:08, remaining: 0:03:30)
# Exported lines 875-879 to steam_app_data2.csv. Batch 175 time: 0:00:08 (avg: 0:00:08, remaining: 0:03:21)
# Exported lines 880-884 to steam_app_data2.csv. Batch 176 time: 0:00:08 (avg: 0:00:08, remaining: 0:03:13)
# Exported lines 885-889 to steam_app_data2.csv. Batch 177 time: 0:00:08 (avg: 0:00:08, remaining: 0:03:05)
# Exported lines 890-894 to steam_app_data2.csv. Batch 178 time: 0:00:08 (avg: 0:00:08, remaining: 0:02:57)
# Exported lines 895-899 to steam_app_data2.csv. Batch 179 time: 0:00:08 (avg: 0:00:08, remaining: 0:02:49)
# Exported lines 900-904 to steam_app_data2.csv. Batch 180 time: 0:00:08 (avg: 0:00:08, remaining: 0:02:41)
# Exported lines 905-909 to steam_app_data2.csv. Batch 181 time: 0:00:08 (avg: 0:00:08, remaining: 0:02:33)
# Exported lines 910-914 to steam_app_data2.csv. Batch 182 time: 0:00:08 (avg: 0:00:08, remaining: 0:02:25)
# Exported lines 915-919 to steam_app_data2.csv. Batch 183 time: 0:00:08 (avg: 0:00:08, remaining: 0:02:17)
# Exported lines 920-924 to steam_app_data2.csv. Batch 184 time: 0:00:08 (avg: 0:00:08, remaining: 0:02:09)
# Exported lines 925-929 to steam_app_data2.csv. Batch 185 time: 0:00:08 (avg: 0:00:08, remaining: 0:02:01)
# Exported lines 930-934 to steam_app_data2.csv. Batch 186 time: 0:00:08 (avg: 0:00:08, remaining: 0:01:53)
# Exported lines 935-939 to steam_app_data2.csv. Batch 187 time: 0:00:08 (avg: 0:00:08, remaining: 0:01:45)
# Exported lines 940-944 to steam_app_data2.csv. Batch 188 time: 0:00:08 (avg: 0:00:08, remaining: 0:01:37)
# Exported lines 945-949 to steam_app_data2.csv. Batch 189 time: 0:00:08 (avg: 0:00:08, remaining: 0:01:29)
# Exported lines 950-954 to steam_app_data2.csv. Batch 190 time: 0:00:08 (avg: 0:00:08, remaining: 0:01:21)
# Exported lines 955-959 to steam_app_data2.csv. Batch 191 time: 0:00:08 (avg: 0:00:08, remaining: 0:01:12)
# Exported lines 960-964 to steam_app_data2.csv. Batch 192 time: 0:00:08 (avg: 0:00:08, remaining: 0:01:04)
# Exported lines 965-969 to steam_app_data2.csv. Batch 193 time: 0:00:08 (avg: 0:00:08, remaining: 0:00:56)
# Exported lines 970-974 to steam_app_data2.csv. Batch 194 time: 0:00:08 (avg: 0:00:08, remaining: 0:00:48)
# Exported lines 975-979 to steam_app_data2.csv. Batch 195 time: 0:00:08 (avg: 0:00:08, remaining: 0:00:40)
# Exported lines 980-984 to steam_app_data2.csv. Batch 196 time: 0:00:08 (avg: 0:00:08, remaining: 0:00:32)
# Exported lines 985-989 to steam_app_data2.csv. Batch 197 time: 0:00:08 (avg: 0:00:08, remaining: 0:00:24)
# Exported lines 990-994 to steam_app_data2.csv. Batch 198 time: 0:00:08 (avg: 0:00:08, remaining: 0:00:16)
# Exported lines 995-999 to steam_app_data2.csv. Batch 199 time: 0:00:08 (avg: 0:00:08, remaining: 0:00:08)
# Exported lines 1000-1000 to steam_app_data2.csv. Batch 200 time: 0:00:02 (avg: 0:00:08, remaining: 0:00:00)
#
# Processing batches complete. 1000 apps written

# %%
for page in range(2, 16):
    url = "https://steamspy.com/api.php"
    parameters = {"request": "all", 'page' : page}

    # request 'all' from steam spy and parse into dataframe
    json_data = get_request(url, parameters=parameters)
    steam_spy_all = pd.DataFrame.from_dict(json_data, orient='index')

    # generate sorted app_list from steamspy data
    app_list = steam_spy_all[['appid', 'name']].sort_values('appid').reset_index(drop=True)

    # export disabled to keep consistency across download sessions
    app_list.to_csv('./data/download/app_list'+str(page+1)+'.csv', index=False)

    # instead read from stored csv
    app_list = pd.read_csv('./data/download/app_list'+str(page+1)+'.csv')

    # Set file parameters
    download_path = './data/download'
    steam_app_data = 'steam_app_data'+str(page+1)+'.csv'
    steam_index = 'steam_index.txt'

    steam_columns = [
        'type', 'name', 'steam_appid', 'required_age', 'is_free', 'controller_support',
        'dlc', 'detailed_description', 'about_the_game', 'short_description', 'fullgame',
        'supported_languages', 'header_image', 'website', 'pc_requirements', 'mac_requirements',
        'linux_requirements', 'legal_notice', 'drm_notice', 'ext_user_account_notice',
        'developers', 'publishers', 'demos', 'price_overview', 'packages', 'package_groups',
        'platforms', 'metacritic', 'reviews', 'categories', 'genres', 'screenshots',
        'movies', 'recommendations', 'achievements', 'release_date', 'support_info',
        'background', 'content_descriptors'
    ]

    # Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
    reset_index(download_path, steam_index)

    # Retrieve last index downloaded from file
    index = get_index(download_path, steam_index)

    # Wipe or create data file and write headers if index is 0
    prepare_data_file(download_path, steam_app_data, index, steam_columns)

    # Set end and chunksize for demonstration - remove to run through entire app list
    process_batches(
        parser=parse_steam_request,
        app_list=app_list,
        download_path=download_path,
        data_filename=steam_app_data,
        index_filename=steam_index,
        columns=steam_columns,
        begin=index
    )
# Out:
# Starting at index 0:
#
# Exported lines 0-99 to steam_app_data3.csv. Batch 0 time: 0:02:09 (avg: 0:02:09, remaining: 0:21:32)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 100-199 to steam_app_data3.csv. Batch 1 time: 0:02:35 (avg: 0:02:22, remaining: 0:21:17)
# Exported lines 200-299 to steam_app_data3.csv. Batch 2 time: 0:02:14 (avg: 0:02:19, remaining: 0:18:33)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 300-399 to steam_app_data3.csv. Batch 3 time: 0:02:43 (avg: 0:02:25, remaining: 0:16:56)
# Exported lines 400-499 to steam_app_data3.csv. Batch 4 time: 0:02:12 (avg: 0:02:23, remaining: 0:14:15)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 500-599 to steam_app_data3.csv. Batch 5 time: 0:02:51 (avg: 0:02:27, remaining: 0:12:17)
# Exported lines 600-699 to steam_app_data3.csv. Batch 6 time: 0:02:17 (avg: 0:02:26, remaining: 0:09:44)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 700-799 to steam_app_data3.csv. Batch 7 time: 0:02:41 (avg: 0:02:28, remaining: 0:07:23)
# Exported lines 800-899 to steam_app_data3.csv. Batch 8 time: 0:02:11 (avg: 0:02:26, remaining: 0:04:52)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 900-999 to steam_app_data3.csv. Batch 9 time: 0:02:51 (avg: 0:02:28, remaining: 0:02:28)
# Exported lines 1000-1000 to steam_app_data3.csv. Batch 10 time: 0:00:02 (avg: 0:02:15, remaining: 0:00:00)
#
# Processing batches complete. 1000 apps written
# Starting at index 0:
#
# Exported lines 0-99 to steam_app_data4.csv. Batch 0 time: 0:02:10 (avg: 0:02:10, remaining: 0:21:37)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 100-199 to steam_app_data4.csv. Batch 1 time: 0:02:56 (avg: 0:02:33, remaining: 0:22:55)
# Exported lines 200-299 to steam_app_data4.csv. Batch 2 time: 0:02:14 (avg: 0:02:27, remaining: 0:19:33)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 300-399 to steam_app_data4.csv. Batch 3 time: 0:02:46 (avg: 0:02:31, remaining: 0:17:40)
# Exported lines 400-499 to steam_app_data4.csv. Batch 4 time: 0:02:14 (avg: 0:02:28, remaining: 0:14:48)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 500-599 to steam_app_data4.csv. Batch 5 time: 0:02:43 (avg: 0:02:30, remaining: 0:12:32)
# Exported lines 600-699 to steam_app_data4.csv. Batch 6 time: 0:02:12 (avg: 0:02:28, remaining: 0:09:51)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 700-799 to steam_app_data4.csv. Batch 7 time: 0:02:42 (avg: 0:02:30, remaining: 0:07:29)
# Exported lines 800-899 to steam_app_data4.csv. Batch 8 time: 0:02:09 (avg: 0:02:27, remaining: 0:04:55)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 900-999 to steam_app_data4.csv. Batch 9 time: 0:02:51 (avg: 0:02:30, remaining: 0:02:30)
# Exported lines 1000-1000 to steam_app_data4.csv. Batch 10 time: 0:00:02 (avg: 0:02:16, remaining: 0:00:00)
#
# Processing batches complete. 1000 apps written
# Starting at index 0:
#
# Exported lines 0-99 to steam_app_data5.csv. Batch 0 time: 0:02:11 (avg: 0:02:11, remaining: 0:21:49)
# Current index: 127
# Bad pipe message: %s [b'', b'Q\x1c\xec\x02\xbdquEH\x86\n\x88?]\xb2$ \x06\xaa\x8ab#\xc0W\xfa\xec\x85\xbd.0\x83v9\xe2\xd2\x9e\x9d\xbb9\xdf;U\x00\x9d\x81Y\x089\x96\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00']
# Bad pipe message: %s [b"\x99\xa3LNF\xf57\xcdL\x8fZ\xc0\xba\x13\xd2\x85\xd0\xd7\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00", b'C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r']
# Bad pipe message: %s [b"\x0f!\xb7\x01\xb3\x96\xe5pDL\xf9\x98\xfb+\xfcP\xb7\xe8 \xe5{\x1c\x1eh\x9a\xecJ\xc8\xc6^'V\x85&a@\xa6\xdf;\xc0U-\xc5\xf5\xd8]\x93Z3\xb8\xc5\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00", b'\x1d\x00 dlO\x83\xee\xc5\x101QJI:\xde\xf1]\x9b\x8a$\xa1\x14\x1d\x98p_\xdf\x12"{\x9fE\xbd\x18']
# Bad pipe message: %s [b"ED\xb2\xb1\xadQ4\x15\xb9\x03\x86\xd7\x88\x8d*GY\xca\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x00", b'\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c']
# Bad pipe message: %s [b'\xf4\xbfz\xcfN\xad\x1c\x8a&\xe3\x0f\xc0\xfa\xb7!\x82\xfd\xc6\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\']
# Bad pipe message: %s [b'\xf1\xb9\xe7\xc8(\x8d6#\xa3\xe1r.\x0c\x0e\x1b\xef>\xab\x00']
# Bad pipe message: %s [b'\x9f\xc0\xc9\x8dc\xd3\x01.9\x9b{\xb7|Mw\x10\xd0\x13\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0']
# Bad pipe message: %s [b"\x8e\x80\xf3\x1c\x7f\xb4D\xc7A\xe89\x9ew\xa7\x04\xae\xd1t\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00g\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\r\x00 \x00\x1e\x06\x01\x06\x02\x06\x03\x05\x01\x05\x02\x05\x03\x04\x01\x04\x02\x04\x03\x03\x01\x03\x02"]
# Bad pipe message: %s [b'\xcb\xfd/\xe4\x11\xc5{\x978O|\xa0\t\xc2+\x1f\xb7\xf7\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x15\x03\x00\x00\x02\x02(']
# Bad pipe message: %s [b'\x02\x01', b'\x02']
# Bad pipe message: %s [b'\x15\xc0\x0b\xc0\x01']
# Bad pipe message: %s [b"\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08"]
# Bad pipe message: %s [b'\x0f\x00']
# Bad pipe message: %s [b'\n\x08\x0b\x08\x04\x08\x05\x08']
# Bad pipe message: %s [b'\x01\x05\x01\x06\x01']
# Bad pipe message: %s [b'\x02\x03', b'\x02\x01', b'\x02\x02']
# Bad pipe message: %s [b'\x05\x02\x06']
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Current index: 174

# %%
range(2,10)
# Out:
# range(2, 10)
